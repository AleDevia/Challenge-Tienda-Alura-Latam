# %% [markdown]
# <a href="https://colab.research.google.com/github/AleDevia/Challenge-Tienda-Alura-Latam/blob/main/Tarea_Alura_Latam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

Venta_total_tienda1 = sum(tienda1["Precio"])
Venta_total_tienda2 = sum(tienda2["Precio"])
Venta_total_tienda3 = sum(tienda3["Precio"])
Venta_total_tienda4 = sum(tienda4["Precio"])


print(f"Venta total: {Venta_total_tienda1:,.0f}")
print(f"Venta total: {Venta_total_tienda2:,.0f}")
print(f"Venta total: {Venta_total_tienda3:,.0f}")
print(f"Venta total: {Venta_total_tienda4:,.0f}")
# Out:
# Venta total: 1,150,880,400
# Venta total: 1,116,343,500
# Venta total: 1,098,019,600
# Venta total: 1,038,375,700

# %%
#Graficar ventas por tienda

import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"])
y = np.array([Venta_total_tienda1, Venta_total_tienda2, Venta_total_tienda3, Venta_total_tienda4])

tiendas = ['Tienda1', 'Tienda2','Tienda3','Tienda4']
valores_tiendas = [Venta_total_tienda1, Venta_total_tienda2, Venta_total_tienda3, Venta_total_tienda4]

plt.title('Ventas por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Ventas')



plt.bar(x,y)
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

ventas_por_categoria = {}
for nombre, df in ('Tienda 1', tienda1), ('Tienda 2', tienda2), ('Tienda 3', tienda3), ('Tienda 4', tienda4):
  conteo = df['Categoría del Producto'].value_counts()
  ventas_por_categoria[nombre]=conteo

  conteo_tienda1 = tienda1['Categoría del Producto'].value_counts()
  conteo_tienda2 = tienda2['Categoría del Producto'].value_counts()
  conteo_tienda3 = tienda3['Categoría del Producto'].value_counts()
  conteo_tienda4 = tienda4['Categoría del Producto'].value_counts()

ventas_por_categoria = pd.DataFrame(ventas_por_categoria)
ventas_por_categoria.fillna(0, inplace=True)
ventas_por_categoria

display(ventas_por_categoria)
# Out:
#                          Tienda 1  Tienda 2  Tienda 3  Tienda 4
# Categoría del Producto
# Artículos para el hogar       171       181       177       201
# Deportes y diversión          284       275       277       277
# Electrodomésticos             312       305       278       254
# Electrónicos                  448       422       451       451
# Instrumentos musicales        182       224       177       170
# Juguetes                      324       313       315       338
# Libros                        173       197       185       187
# Muebles                       465       442       499       480

# %%
ventas_por_categoria.plot.bar()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

Calificacion_promedio_tienda1 = tienda1["Calificación"].mean()
Calificacion_promedio_tienda2 = tienda2["Calificación"].mean()
Calificacion_promedio_tienda3 = tienda3["Calificación"].mean()
Calificacion_promedio_tienda4 = tienda4["Calificación"].mean()


print(f"Calificacion_promedio: {Calificacion_promedio_tienda1:,.2f}")
print(f"Calificacion_promedio: {Calificacion_promedio_tienda2:,.2f}")
print(f"Calificacion_promedio: {Calificacion_promedio_tienda3:,.2f}")
print(f"Calificacion_promedio: {Calificacion_promedio_tienda4:,.2f}")
# Out:
# Calificacion_promedio: 3.98
# Calificacion_promedio: 4.04
# Calificacion_promedio: 4.05
# Calificacion_promedio: 4.00

# %%
tiendas = ['Tienda1', 'Tienda2','Tienda3','Tienda4']
Calificacion_promedio_tienda = [Calificacion_promedio_tienda1, Calificacion_promedio_tienda2, Calificacion_promedio_tienda3, Calificacion_promedio_tienda4]

plt.title('Calificacion promedio por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Calificacion promedio')

plt.bar(tiendas, Calificacion_promedio_tienda)
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd

# URLs de los archivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Diccionario con las URLs de las tiendas
tiendas = {
    'Tienda 1': url,
    'Tienda 2': url2,
    'Tienda 3': url3,
    'Tienda 4': url4
}


def productos_mas_y_menos_vendidos_por_tienda(tiendas):
    resultados = []

    for nombre_tienda, url in tiendas.items():

        df = pd.read_csv(url)

        ventas_por_producto = df['Producto'].value_counts().reset_index()
        ventas_por_producto.columns = ['Producto', 'Total Ventas']


        productos_top = ventas_por_producto.head(3)


        productos_bottom = ventas_por_producto.tail(3)


        for i in range(3):  # Iterar sobre los 3 productos más y menos vendidos
            resultados.append({
                'Tienda': nombre_tienda,
                'Producto Más Vendido': productos_top.iloc[i]['Producto'] if i < len(productos_top) else None,
                'Total Ventas (Más Vendido)': productos_top.iloc[i]['Total Ventas'] if i < len(productos_top) else None,
                'Producto Menos Vendido': productos_bottom.iloc[i]['Producto'] if i < len(productos_bottom) else None,
                'Total Ventas (Menos Vendido)': productos_bottom.iloc[i]['Total Ventas'] if i < len(productos_bottom) else None
            })

    return pd.DataFrame(resultados)


resultado_final = productos_mas_y_menos_vendidos_por_tienda(tiendas)


resultado_final = resultado_final[['Tienda', 'Producto Más Vendido','Total Ventas (Más Vendido)', 'Producto Menos Vendido',  'Total Ventas (Menos Vendido)']]


resultado_final['Total Ventas (Más Vendido)'] = resultado_final['Total Ventas (Más Vendido)'].map('{:,.0f}'.format)
resultado_final['Total Ventas (Menos Vendido)'] = resultado_final['Total Ventas (Menos Vendido)'].map('{:,.0f}'.format)


styled_df = resultado_final.style.set_properties(**{'text-align': 'center'})




styled_df .set_caption('Productos Más y Menos Vendidos por Tienda')
# Out:
# <style type="text/css">
# #T_0c530_row0_col0, #T_0c530_row0_col1, #T_0c530_row0_col2, #T_0c530_row0_col3, #T_0c530_row0_col4, #T_0c530_row1_col0, #T_0c530_row1_col1, #T_0c530_row1_col2, #T_0c530_row1_col3, #T_0c530_row1_col4, #T_0c530_row2_col0, #T_0c530_row2_col1, #T_0c530_row2_col2, #T_0c530_row2_col3, #T_0c530_row2_col4, #T_0c530_row3_col0, #T_0c530_row3_col1, #T_0c530_row3_col2, #T_0c530_row3_col3, #T_0c530_row3_col4, #T_0c530_row4_col0, #T_0c530_row4_col1, #T_0c530_row4_col2, #T_0c530_row4_col3, #T_0c530_row4_col4, #T_0c530_row5_col0, #T_0c530_row5_col1, #T_0c530_row5_col2, #T_0c530_row5_col3, #T_0c530_row5_col4, #T_0c530_row6_col0, #T_0c530_row6_col1, #T_0c530_row6_col2, #T_0c530_row6_col3, #T_0c530_row6_col4, #T_0c530_row7_col0, #T_0c530_row7_col1, #T_0c530_row7_col2, #T_0c530_row7_col3, #T_0c530_row7_col4, #T_0c530_row8_col0, #T_0c530_row8_col1, #T_0c530_row8_col2, #T_0c530_row8_col3, #T_0c530_row8_col4, #T_0c530_row9_col0, #T_0c530_row9_col1, #T_0c530_row9_col2, #T_0c530_row9_col3, #T_0c530_row9_col4, #T_0c530_row10_col0, #T_0c530_row10_col1, #T_0c530_row10_col2, #T_0c530_row10_col3, #T_0c530_row10_col4, #T_0c530_row11_col0, #T_0c530_row11_col1, #T_0c530_row11_col2, #T_0c530_row11_col3, #T_0c530_row11_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_0c530" class="dataframe">
#   <caption>Productos Más y Menos Vendidos por Tienda</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c530_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_0c530_level0_col1" class="col_heading level0 col1" >Producto Más Vendido</th>
#       <th id="T_0c530_level0_col2" class="col_heading level0 col2" >Total Ventas (Más Vendido)</th>
#       <th id="T_0c530_level0_col3" class="col_heading level0 col3" >Producto Menos Vendido</th>
#       <th id="T_0c530_level0_col4" class="col_heading level0 col4" >Total Ventas (Menos Vendido)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c530_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c530_row0_col0" class="data row0 col0" >Tienda 1</td>
#       <td id="T_0c530_row0_col1" class="data row0 col1" >Microondas</td>
#       <td id="T_0c530_row0_col2" class="data row0 col2" >60</td>
#       <td id="T_0c530_row0_col3" class="data row0 col3" >Olla de presión</td>
#       <td id="T_0c530_row0_col4" class="data row0 col4" >35</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c530_row1_col0" class="data row1 col0" >Tienda 1</td>
#       <td id="T_0c530_row1_col1" class="data row1 col1" >TV LED UHD 4K</td>
#       <td id="T_0c530_row1_col2" class="data row1 col2" >60</td>
#       <td id="T_0c530_row1_col3" class="data row1 col3" >Auriculares con micrófono</td>
#       <td id="T_0c530_row1_col4" class="data row1 col4" >33</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c530_row2_col0" class="data row2 col0" >Tienda 1</td>
#       <td id="T_0c530_row2_col1" class="data row2 col1" >Armario</td>
#       <td id="T_0c530_row2_col2" class="data row2 col2" >60</td>
#       <td id="T_0c530_row2_col3" class="data row2 col3" >Celular ABXY</td>
#       <td id="T_0c530_row2_col4" class="data row2 col4" >33</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c530_row3_col0" class="data row3 col0" >Tienda 2</td>
#       <td id="T_0c530_row3_col1" class="data row3 col1" >Iniciando en programación</td>
#       <td id="T_0c530_row3_col2" class="data row3 col2" >65</td>
#       <td id="T_0c530_row3_col3" class="data row3 col3" >Mesa de comedor</td>
#       <td id="T_0c530_row3_col4" class="data row3 col4" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c530_row4_col0" class="data row4 col0" >Tienda 2</td>
#       <td id="T_0c530_row4_col1" class="data row4 col1" >Microondas</td>
#       <td id="T_0c530_row4_col2" class="data row4 col2" >62</td>
#       <td id="T_0c530_row4_col3" class="data row4 col3" >Impresora</td>
#       <td id="T_0c530_row4_col4" class="data row4 col4" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c530_row5_col0" class="data row5 col0" >Tienda 2</td>
#       <td id="T_0c530_row5_col1" class="data row5 col1" >Batería</td>
#       <td id="T_0c530_row5_col2" class="data row5 col2" >61</td>
#       <td id="T_0c530_row5_col3" class="data row5 col3" >Juego de mesa</td>
#       <td id="T_0c530_row5_col4" class="data row5 col4" >32</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c530_row6_col0" class="data row6 col0" >Tienda 3</td>
#       <td id="T_0c530_row6_col1" class="data row6 col1" >Kit de bancas</td>
#       <td id="T_0c530_row6_col2" class="data row6 col2" >57</td>
#       <td id="T_0c530_row6_col3" class="data row6 col3" >Mochila</td>
#       <td id="T_0c530_row6_col4" class="data row6 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c530_row7_col0" class="data row7 col0" >Tienda 3</td>
#       <td id="T_0c530_row7_col1" class="data row7 col1" >Mesa de comedor</td>
#       <td id="T_0c530_row7_col2" class="data row7 col2" >56</td>
#       <td id="T_0c530_row7_col3" class="data row7 col3" >Microondas</td>
#       <td id="T_0c530_row7_col4" class="data row7 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c530_row8_col0" class="data row8 col0" >Tienda 3</td>
#       <td id="T_0c530_row8_col1" class="data row8 col1" >Cama king</td>
#       <td id="T_0c530_row8_col2" class="data row8 col2" >56</td>
#       <td id="T_0c530_row8_col3" class="data row8 col3" >Bloques de construcción</td>
#       <td id="T_0c530_row8_col4" class="data row8 col4" >35</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c530_row9_col0" class="data row9 col0" >Tienda 4</td>
#       <td id="T_0c530_row9_col1" class="data row9 col1" >Cama box</td>
#       <td id="T_0c530_row9_col2" class="data row9 col2" >62</td>
#       <td id="T_0c530_row9_col3" class="data row9 col3" >Guitarra acústica</td>
#       <td id="T_0c530_row9_col4" class="data row9 col4" >37</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0c530_row10_col0" class="data row10 col0" >Tienda 4</td>
#       <td id="T_0c530_row10_col1" class="data row10 col1" >Cubertería</td>
#       <td id="T_0c530_row10_col2" class="data row10 col2" >59</td>
#       <td id="T_0c530_row10_col3" class="data row10 col3" >Armario</td>
#       <td id="T_0c530_row10_col4" class="data row10 col4" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0c530_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0c530_row11_col0" class="data row11 col0" >Tienda 4</td>
#       <td id="T_0c530_row11_col1" class="data row11 col1" >Dashboards con Power BI</td>
#       <td id="T_0c530_row11_col2" class="data row11 col2" >56</td>
#       <td id="T_0c530_row11_col3" class="data row11 col3" >Guitarra eléctrica</td>
#       <td id="T_0c530_row11_col4" class="data row11 col4" >33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd
import numpy as np


url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"


tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)


def calcular_envio_promedio(df, nombre_tienda):
    promedio_envio = df['Costo de envío'].mean()  # Asumiendo que la columna de envíos se llama 'Costo de envío'
    return {
        'Tienda': nombre_tienda,
        'Promedio de envío': promedio_envio
    }


resultados_envios = [
    calcular_envio_promedio(tienda, 'Tienda 1'),
    calcular_envio_promedio(tienda2, 'Tienda 2'),
    calcular_envio_promedio(tienda3, 'Tienda 3'),
    calcular_envio_promedio(tienda4, 'Tienda 4')
]


df_envios = pd.DataFrame(resultados_envios)
df_envios = df_envios.round(4)


df_envios_styled = df_envios.style.set_properties(
    **{'text-align': 'left'}, subset=['Tienda']
).set_properties(
    **{'text-align': 'right'}, subset=['Promedio de envío']
)

df_envios_styled
# Out:
# <style type="text/css">
# #T_47dc7_row0_col0, #T_47dc7_row1_col0, #T_47dc7_row2_col0, #T_47dc7_row3_col0 {
#   text-align: left;
# }
# #T_47dc7_row0_col1, #T_47dc7_row1_col1, #T_47dc7_row2_col1, #T_47dc7_row3_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_47dc7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47dc7_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_47dc7_level0_col1" class="col_heading level0 col1" >Promedio de envío</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47dc7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47dc7_row0_col0" class="data row0 col0" >Tienda 1</td>
#       <td id="T_47dc7_row0_col1" class="data row0 col1" >26018.609600</td>
#     </tr>
#     <tr>
#       <th id="T_47dc7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47dc7_row1_col0" class="data row1 col0" >Tienda 2</td>
#       <td id="T_47dc7_row1_col1" class="data row1 col1" >25216.235700</td>
#     </tr>
#     <tr>
#       <th id="T_47dc7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47dc7_row2_col0" class="data row2 col0" >Tienda 3</td>
#       <td id="T_47dc7_row2_col1" class="data row2 col1" >24805.680400</td>
#     </tr>
#     <tr>
#       <th id="T_47dc7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_47dc7_row3_col0" class="data row3 col0" >Tienda 4</td>
#       <td id="T_47dc7_row3_col1" class="data row3 col1" >23459.457200</td>
#     </tr>
#   </tbody>
# </table>
